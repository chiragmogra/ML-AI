# %% [markdown]
# <a href="https://colab.research.google.com/github/chiragmogra/ML-AI_assignments/blob/master/comp_vision_L1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

# %%
print(cv2.__version__)
# Out:
# 3.4.3

# %%
# images read
img=cv2.imread('dog.jfif')
img
# Out:
# array([[[ 56,  85,  90],
#         [ 56,  85,  90],
#         [ 57,  86,  90],
#         ...,
#         [ 61, 122, 142],
#         [ 52, 118, 137],
#         [ 45, 113, 132]],
#
#        [[ 57,  85,  92],
#         [ 57,  86,  91],
#         [ 58,  87,  92],
#         ...,
#         [ 61, 122, 142],
#         [ 55, 119, 137],
#         [ 43, 111, 130]],
#
#        [[ 58,  87,  96],
#         [ 58,  87,  94],
#         [ 59,  88,  95],
#         ...,
#         [ 61, 120, 139],
#         [ 56, 118, 134],
#         [ 42, 108, 126]],
#
#        ...,
#
#        [[141, 144, 149],
#         [126, 129, 134],
#         [143, 146, 151],
#         ...,
#         [168, 172, 177],
#         [163, 169, 174],
#         [162, 168, 173]],
#
#        [[ 93,  96, 101],
#         [142, 145, 149],
#         [155, 158, 162],
#         ...,
#         [150, 154, 159],
#         [139, 145, 150],
#         [155, 161, 166]],
#
#        [[128, 131, 135],
#         [139, 142, 146],
#         [149, 152, 156],
# ...

# %%
# print shape
print(img.shape)
# Out:
# (185, 273, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# to display image
plt.imshow(img)

# %%
img=cv2.imread('dog.jfif',0)
plt.imshow(img)

# %%
img=cv2.imread('dog.jfif',1)
plt.imshow(img)

# %%
 img=cv2.imread('dog.jfif',-1)
plt.imshow(img)

# %%
 g
